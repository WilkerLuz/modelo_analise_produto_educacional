# %%
# Importando as bibliotecas pandas, matplolib e numpy

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#Iportando o Arquivo CSV para a análise dos dados, 
#Abaixo será gerado um DataFrame para a manipulação usando o Pandas

analise_notas_df = pd.read_csv('analises_notas.csv')
df_atividade_4 = pd.read_csv('vpl_atividade_04_com_engajamento.csv')

# %%
analise_notas_df
# Out:
#    NOME_ALUNO  USERID  NotaCP  Nota1  Nota2  Nota3  Experiencia  \
# 0    aluno 01      63   0.000  10.00  10.00   0.00            2
# 1    aluno 02      56   7.275  10.00  10.00  10.00            2
# 2    aluno 03      41   5.410  10.00  10.00  10.00            1
# 3    aluno 04      25   3.125   5.00  10.00  10.00            2
# 4    aluno 05      26   7.695   4.51  10.00  10.00            3
# 5    aluno 06      20   3.330   5.00  10.00   0.00            3
# 6    aluno 07      43   3.330   4.51  10.00  10.00            2
# 7    aluno 08      65   0.000   0.00   0.00   0.00            3
# 8    aluno 09      40   0.830  10.00   0.00   0.00            2
# 9    aluno 10      50   6.240   5.00   8.75   5.00            2
# 10   aluno 11      35   6.660  10.00  10.00  10.00            2
# 11   aluno 12      36   5.615  10.00  10.00  10.00            3
# 12   aluno 13      34   5.410   4.50  10.00  10.00            1
# 13   aluno 14      48   7.285   4.51  10.00  10.00            1
# ...

# %%
df_atividade_4
# Out:
#    NOME_ALUNO  Questão 01  Questão 02  Questão 03  Questão 04  Questão 05  \
# 0    aluno 01        10.0        10.0        10.0        10.0        10.0
# 1    aluno 02        10.0        10.0        10.0        10.0         0.0
# 2    aluno 03         0.0        10.0        10.0        10.0         0.0
# 3    aluno 04        10.0        10.0        10.0        10.0        10.0
# 4    aluno 05        10.0        10.0        10.0        10.0        10.0
# 5    aluno 06         0.0         0.0        10.0        10.0         0.0
# 6    aluno 07        10.0        10.0        10.0        10.0        10.0
# 7    aluno 08        10.0        10.0        10.0        10.0        10.0
# 8    aluno 09        10.0        10.0        10.0        10.0        10.0
# 9    aluno 10        10.0        10.0        10.0        10.0        10.0
# 10   aluno 11        10.0        10.0        10.0        10.0        10.0
# 11   aluno 12        10.0        10.0        10.0        10.0        10.0
# ...

# %%
analise_notas_df = analise_notas_df.merge(df_atividade_4[['NOME_ALUNO', 'Media_Notas']], on='NOME_ALUNO', how='left', suffixes=('_atividade_4', '_atividade_4'))

analise_notas_df
# Out:
#    NOME_ALUNO  USERID  NotaCP  Nota1  Nota2  Nota3  Experiencia  \
# 0    aluno 01      63   0.000  10.00  10.00   0.00            2
# 1    aluno 02      56   7.275  10.00  10.00  10.00            2
# 2    aluno 03      41   5.410  10.00  10.00  10.00            1
# 3    aluno 04      25   3.125   5.00  10.00  10.00            2
# 4    aluno 05      26   7.695   4.51  10.00  10.00            3
# 5    aluno 06      20   3.330   5.00  10.00   0.00            3
# 6    aluno 07      43   3.330   4.51  10.00  10.00            2
# 7    aluno 08      65   0.000   0.00   0.00   0.00            3
# 8    aluno 09      40   0.830  10.00   0.00   0.00            2
# 9    aluno 10      50   6.240   5.00   8.75   5.00            2
# 10   aluno 11      35   6.660  10.00  10.00  10.00            2
# 11   aluno 12      36   5.615  10.00  10.00  10.00            3
# 12   aluno 13      34   5.410   4.50  10.00  10.00            1
# 13   aluno 14      48   7.285   4.51  10.00  10.00            1
# ...

# %%
analise_notas_df.rename(columns={'Media_Notas': 'Nota4'}, inplace=True)

analise_notas_df
# Out:
#    NOME_ALUNO  USERID  NotaCP  Nota1  Nota2  Nota3  Experiencia  \
# 0    aluno 01      63   0.000  10.00  10.00   0.00            2
# 1    aluno 02      56   7.275  10.00  10.00  10.00            2
# 2    aluno 03      41   5.410  10.00  10.00  10.00            1
# 3    aluno 04      25   3.125   5.00  10.00  10.00            2
# 4    aluno 05      26   7.695   4.51  10.00  10.00            3
# 5    aluno 06      20   3.330   5.00  10.00   0.00            3
# 6    aluno 07      43   3.330   4.51  10.00  10.00            2
# 7    aluno 08      65   0.000   0.00   0.00   0.00            3
# 8    aluno 09      40   0.830  10.00   0.00   0.00            2
# 9    aluno 10      50   6.240   5.00   8.75   5.00            2
# 10   aluno 11      35   6.660  10.00  10.00  10.00            2
# 11   aluno 12      36   5.615  10.00  10.00  10.00            3
# 12   aluno 13      34   5.410   4.50  10.00  10.00            1
# 13   aluno 14      48   7.285   4.51  10.00  10.00            1
# ...

# %%
analise_notas_df = analise_notas_df.merge(df_atividade_4[['NOME_ALUNO', 'TAXA_ENGAJAMENTO']], on='NOME_ALUNO', how='left', suffixes=('_atividade_4', '_atividade_4'))

analise_notas_df
# Out:
#    NOME_ALUNO  USERID  NotaCP  Nota1  Nota2  Nota3  Experiencia  \
# 0    aluno 01      63   0.000  10.00  10.00   0.00            2
# 1    aluno 02      56   7.275  10.00  10.00  10.00            2
# 2    aluno 03      41   5.410  10.00  10.00  10.00            1
# 3    aluno 04      25   3.125   5.00  10.00  10.00            2
# 4    aluno 05      26   7.695   4.51  10.00  10.00            3
# 5    aluno 06      20   3.330   5.00  10.00   0.00            3
# 6    aluno 07      43   3.330   4.51  10.00  10.00            2
# 7    aluno 08      65   0.000   0.00   0.00   0.00            3
# 8    aluno 09      40   0.830  10.00   0.00   0.00            2
# 9    aluno 10      50   6.240   5.00   8.75   5.00            2
# 10   aluno 11      35   6.660  10.00  10.00  10.00            2
# 11   aluno 12      36   5.615  10.00  10.00  10.00            3
# 12   aluno 13      34   5.410   4.50  10.00  10.00            1
# 13   aluno 14      48   7.285   4.51  10.00  10.00            1
# ...

# %%
analise_notas_df.rename(columns={'TAXA_ENGAJAMENTO': 'engajamento_n4'}, inplace=True)

analise_notas_df
# Out:
#    NOME_ALUNO  USERID  NotaCP  Nota1  Nota2  Nota3  Experiencia  \
# 0    aluno 01      63   0.000  10.00  10.00   0.00            2
# 1    aluno 02      56   7.275  10.00  10.00  10.00            2
# 2    aluno 03      41   5.410  10.00  10.00  10.00            1
# 3    aluno 04      25   3.125   5.00  10.00  10.00            2
# 4    aluno 05      26   7.695   4.51  10.00  10.00            3
# 5    aluno 06      20   3.330   5.00  10.00   0.00            3
# 6    aluno 07      43   3.330   4.51  10.00  10.00            2
# 7    aluno 08      65   0.000   0.00   0.00   0.00            3
# 8    aluno 09      40   0.830  10.00   0.00   0.00            2
# 9    aluno 10      50   6.240   5.00   8.75   5.00            2
# 10   aluno 11      35   6.660  10.00  10.00  10.00            2
# 11   aluno 12      36   5.615  10.00  10.00  10.00            3
# 12   aluno 13      34   5.410   4.50  10.00  10.00            1
# 13   aluno 14      48   7.285   4.51  10.00  10.00            1
# ...

# %%
analise_notas_df['engajamento_n4_media'] = (analise_notas_df['Engajamento_ant'] + analise_notas_df['engajamento_n4'])/2

analise_notas_df
# Out:
#    NOME_ALUNO  USERID  NotaCP  Nota1  Nota2  Nota3  Experiencia  \
# 0    aluno 01      63   0.000  10.00  10.00   0.00            2
# 1    aluno 02      56   7.275  10.00  10.00  10.00            2
# 2    aluno 03      41   5.410  10.00  10.00  10.00            1
# 3    aluno 04      25   3.125   5.00  10.00  10.00            2
# 4    aluno 05      26   7.695   4.51  10.00  10.00            3
# 5    aluno 06      20   3.330   5.00  10.00   0.00            3
# 6    aluno 07      43   3.330   4.51  10.00  10.00            2
# 7    aluno 08      65   0.000   0.00   0.00   0.00            3
# 8    aluno 09      40   0.830  10.00   0.00   0.00            2
# 9    aluno 10      50   6.240   5.00   8.75   5.00            2
# 10   aluno 11      35   6.660  10.00  10.00  10.00            2
# 11   aluno 12      36   5.615  10.00  10.00  10.00            3
# 12   aluno 13      34   5.410   4.50  10.00  10.00            1
# 13   aluno 14      48   7.285   4.51  10.00  10.00            1
# ...

# %%
df_atividade_5 = pd.read_csv('vpl_atividade_05_com_engajamento.csv')

df_atividade_5
# Out:
#                                            NOME_ALUNO  Questão 1  Questão 10  \
# 0                Alexandre Henrique Oliveira de Sousa      10.00        10.0
# 1                                   Alisson vaz silva      10.00        10.0
# 2                       Antonio Wills da Silva Santos      10.00        10.0
# 3                        Carlos Eduardo Lima Coutinho      10.00        10.0
# 4              Crisfieldy Aristodenes Feitoza Ribeiro      10.00        10.0
# 5                         Danielly dos Santos Almeida       6.67        10.0
# 6                         Debriane da Silva Conceição       3.33         5.0
# 7                         Durval Veloso Barbosa Filho      10.00        10.0
# 8                         Evelly Victory Vieira Pinto      10.00        10.0
# 9                Francisco Leonel Ferreira dos Santos      10.00        10.0
# 10                  Gabriel Antonio Assunção Oliveira      10.00        10.0
# ...

# %%
analise_notas_df = analise_notas_df.merge(df_atividade_5[['NOME_ALUNO', 'Media_Notas']], 
                                          on='NOME_ALUNO', how='left', suffixes=('_atividade_5', '_atividade_5'))

analise_notas_df.rename(columns={'Media_Notas': 'Nota5'}, inplace=True)


analise_notas_df = analise_notas_df.merge(df_atividade_4[['NOME_ALUNO', 'TAXA_ENGAJAMENTO']], 
                                          on='NOME_ALUNO', how='left', suffixes=('_atividade_5', '_atividade_5'))

analise_notas_df.rename(columns={'TAXA_ENGAJAMENTO': 'engajamento_n5'}, inplace=True)

analise_notas_df['engajamento_n5_media'] = (analise_notas_df['engajamento_n4'] + analise_notas_df['engajamento_n5'])/2

analise_notas_df
# Out:
#                                            NOME_ALUNO  USERID  NotaCP  Nota1  \
# 0                Alexandre Henrique Oliveira de Sousa      63   0.000  10.00
# 1                                   Alisson vaz silva      56   7.275  10.00
# 2                       Antonio Wills da Silva Santos      41   5.410  10.00
# 3                           Ávila da Conceição Araújo      25   3.125   5.00
# 4                        Carlos Eduardo Lima Coutinho      26   7.695   4.51
# 5              Crisfieldy Aristodenes Feitoza Ribeiro      20   3.330   5.00
# 6                         Danielly dos Santos Almeida      43   3.330   4.51
# 7                         Debriane da Silva Conceição      65   0.000   0.00
# 8                         Durval Veloso Barbosa Filho      40   0.830  10.00
# 9                         Evelly Victory Vieira Pinto      50   6.240   5.00
# 10               Francisco Leonel Ferreira dos Santos      35   6.660  10.00
# ...

# %%
df_atividade_6 = pd.read_csv('vpl_atividade_06_com_engajamento.csv')

df_atividade_6

analise_notas_df = analise_notas_df.merge(df_atividade_6[['NOME_ALUNO', 'Media_Notas']], 
                                          on='NOME_ALUNO', how='left', suffixes=('_atividade_6', '_atividade_6'))

analise_notas_df.rename(columns={'Media_Notas': 'Nota6'}, inplace=True)


analise_notas_df = analise_notas_df.merge(df_atividade_6[['NOME_ALUNO', 'TAXA_ENGAJAMENTO']], 
                                          on='NOME_ALUNO', how='left', suffixes=('_atividade_6', '_atividade_6'))

analise_notas_df.rename(columns={'TAXA_ENGAJAMENTO': 'engajamento_n6'}, inplace=True)

analise_notas_df['engajamento_n6_media'] = (analise_notas_df['engajamento_n5'] + analise_notas_df['engajamento_n6'])/2

analise_notas_df
# Out:
#                                            NOME_ALUNO  USERID  NotaCP  Nota1  \
# 0                Alexandre Henrique Oliveira de Sousa      63   0.000  10.00
# 1                                   Alisson vaz silva      56   7.275  10.00
# 2                       Antonio Wills da Silva Santos      41   5.410  10.00
# 3                           Ávila da Conceição Araújo      25   3.125   5.00
# 4                        Carlos Eduardo Lima Coutinho      26   7.695   4.51
# 5              Crisfieldy Aristodenes Feitoza Ribeiro      20   3.330   5.00
# 6                         Danielly dos Santos Almeida      43   3.330   4.51
# 7                         Debriane da Silva Conceição      65   0.000   0.00
# 8                         Durval Veloso Barbosa Filho      40   0.830  10.00
# 9                         Evelly Victory Vieira Pinto      50   6.240   5.00
# 10               Francisco Leonel Ferreira dos Santos      35   6.660  10.00
# ...
